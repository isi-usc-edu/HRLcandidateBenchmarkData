# %%
import os
import glob

# %%
pstrings = glob.glob('*/*pstring.json')
pstrings
# Out:
# ['2.0_no/2.0_no_pstring.json',
#  '1.0_nis/1.0_nis_pstring.json',
#  '1.5_mnn/1.5_mnn_pstring.json',
#  '1.5_co_n/1.5_co_n_pstring.json',
#  '1.0_of/1.0_of_pstring.json',
#  '2.0_co2/2.0_co2_pstring.json',
#  '11_hehe_2p5_rg10/11_hehe_2p5_rg10_pstring.json',
#  '2.0_co_n/2.0_co_n_pstring.json',
#  '1.0_cun/1.0_cun_pstring.json',
#  '1.0_nih/1.0_nih_pstring.json',
#  '1.5_ch4/1.5_ch4_pstring.json',
#  '1.5_mnh/1.5_mnh_pstring.json',
#  '2.0_beh2/2.0_beh2_pstring.json',
#  '2.0_h2/2.0_h2_pstring.json',
#  '1.0_cus/1.0_cus_pstring.json',
#  '11_hehe_2p9_rg10/11_hehe_2p9_rg10_pstring.json',
#  '1.5_mns/1.5_mns_pstring.json',
#  '1.5_ch2/1.5_ch2_pstring.json',
#  '1.0_c2/1.0_c2_pstring.json',
#  '1.0_cuh/1.0_cuh_pstring.json',
#  '1.5_beh2/1.5_beh2_pstring.json',
#  '1.0_mnh/1.0_mnh_pstring.json',
#  '2.0_crn/2.0_crn_pstring.json',
#  '1.5_cus/1.5_cus_pstring.json',
#  '1.5_of/1.5_of_pstring.json',
#  '1.5_nin/1.5_nin_pstring.json',
#  '1.0_mns/1.0_mns_pstring.json',
# ...

# %%
for pstring in pstrings:
    os.remove(pstring)
glob.glob('*/*pstring.json')

# %%
import numpy as np
import pandas as pd
import glob

# %%
files = glob.glob("*.csv")

# %%
files
# Out:
# ['SHCI.csv',
#  'molpro_energies.csv',
#  'matts_ref_energies.csv',
#  'dft_corrections.csv',
#  'transition_metal_data.csv']

# %%
i=0
# Replace 'your_file.csv' with the path to your CSV file
file_path = files[i]

# Load the CSV file into a DataFrame
df_shci_1 = pd.read_csv(file_path)

df_shci_1
# Out:
#      system basis        SHCI  uncertainty
# 0         h    2z   -0.499278     0.000000
# 1         h    3z   -0.499810     0.000000
# 2         h    4z   -0.499946     0.000000
# 3         h    5z   -0.499995     0.000000
# 4        li    2z   -7.432420     0.000000
# ..      ...   ...         ...          ...
# 263  h_o_cl    5z -535.463443     0.000469
# 264    s_o2    2z -547.717542     0.000135
# 265    s_o2    3z -547.973214     0.000291
# 266    s_o2    4z -548.049552     0.000621
# 267    s_o2    5z -548.080079     0.000312
#
# [268 rows x 4 columns]

# %%
# Replace 'your_file.csv' with the path to your CSV file
file_path = 'matts_ref_energies.csv'

# Load the CSV file into a DataFrame
df_shci_2 = pd.read_csv(file_path)

df_shci_2
# Out:
#          method basis  charge pseudopotential system  totalenergy  \
# 0     AFQMC(MD)   vqz       0           trail     VO   -87.282400
# 1     AFQMC(MD)   vqz       1           trail     Cr   -86.517300
# 2     AFQMC(MD)   vtz       1           trail     Cr   -86.472800
# 3     AFQMC(MD)   vdz       1           trail     Cr   -86.370400
# 4     AFQMC(MD)   v5z       0           trail     Cr   -86.782600
# ...         ...   ...     ...             ...    ...          ...
# 1089    iFCIQMC   vdz       0           trail     Sc   -46.396616
# 1090    iFCIQMC   vdz       1           trail     Sc   -46.156710
# 1091    iFCIQMC   vtz       1           trail      V   -70.919164
# 1092    iFCIQMC   vdz       0           trail    ScO   -62.419317
# 1093    iFCIQMC   vqz       0           trail     Sc   -46.473197
#
#       totalenergy-stocherr  totalenergy-syserr    SHCIref    SHCIreferr  \
# 0                 0.001100                 0.0 -87.288682  1.000000e-05
# ...

# %%
methods = set(())
for val in df_shci_2['method'].values:
    methods.add(val)
methods
# Out:
# {'AFQMC(MD)',
#  'B3LYP',
#  'CISD',
#  'DMC(SD)',
#  'DMRG',
#  'GF2',
#  'HF',
#  'HF+RPA',
#  'HSE06',
#  'HSE06+RPA',
#  'LDA',
#  'MRLCC',
#  'PBE',
#  'QSGW',
#  'SC-GW',
#  'SCAN',
#  'SEET(FCI/GF2)',
#  'SHCI',
#  'UCCSD',
#  'UCCSD(T)',
#  'iFCIQMC'}

# %%
filtered_df = df_shci_2[df_shci_2['method'] == 'SHCI']

ref_gse_df_2 = filtered_df[['system', 'charge', 'basis', 'totalenergy']]

ref_gse_df_3 = ref_gse_df_2.rename(columns={"totalenergy": "SHCI"})
ref_gse_df_3
# Out:
#     system  charge basis       SHCI
# 769    FeO       0   vdz -139.43599
# 770    CuO       0   vdz -213.12303
# 771    TiO       0   vtz  -74.03085
# 772     VO       0   vtz  -87.23526
# 773    CrO       0   vtz -102.71867
# ..     ...     ...   ...        ...
# 856     Mn       1   vqz -103.84272
# 857      O       0   v5z  -15.84317
# 858      O       1   v5z  -15.34479
# 859     Sc       0   v5z  -46.48213
# 860     Cu       1   vqz -197.25343
#
# [92 rows x 4 columns]

# %%
ref_gse_df = df_shci_1[['system', 'basis', 'SHCI']]
ref_gse_df
# Out:
#      system basis        SHCI
# 0         h    2z   -0.499278
# 1         h    3z   -0.499810
# 2         h    4z   -0.499946
# 3         h    5z   -0.499995
# 4        li    2z   -7.432420
# ..      ...   ...         ...
# 263  h_o_cl    5z -535.463443
# 264    s_o2    2z -547.717542
# 265    s_o2    3z -547.973214
# 266    s_o2    4z -548.049552
# 267    s_o2    5z -548.080079
#
# [268 rows x 3 columns]

# %%
shci_ref_db = pd.concat([ref_gse_df, ref_gse_df_3], ignore_index=True)

# Function to check if the entry is a float, convert to string if true, then concatenate
def process_row(row):
    if not pd.isna(row['charge']):  # Check if the entry is a float
        return f"{row['system']}_{str(row['charge'])}"  # Convert to string and concatenate
    else:
        return row['system']  # Return the first column entry as is

# Apply the function to each row
shci_ref_db['system'] = shci_ref_db.apply(process_row, axis=1)

shci_ref_db = shci_ref_db.drop(columns='charge')

shci_ref_db
# Out:
#      system basis        SHCI
# 0         h    2z   -0.499278
# 1         h    3z   -0.499810
# 2         h    4z   -0.499946
# 3         h    5z   -0.499995
# 4        li    2z   -7.432420
# ..      ...   ...         ...
# 355  Mn_1.0   vqz -103.842720
# 356   O_0.0   v5z  -15.843170
# 357   O_1.0   v5z  -15.344790
# 358  Sc_0.0   v5z  -46.482130
# 359  Cu_1.0   vqz -197.253430
#
# [360 rows x 3 columns]

# %%
set(shci_ref_db['basis'].values)
# Out:
# {'2z', '3z', '4z', '5z', 'v5z', 'vdz', 'vqz', 'vtz'}

# %%
systems  = set(shci_ref_db['system'].values)
print(len(systems))
systems
# Out:
# 90
# {'CrO_0.0',
#  'Cr_0.0',
#  'Cr_1.0',
#  'CuO_0.0',
#  'Cu_0.0',
#  'Cu_1.0',
#  'FeO_0.0',
#  'Fe_0.0',
#  'Fe_1.0',
#  'MnO_0.0',
#  'Mn_0.0',
#  'Mn_1.0',
#  'O_0.0',
#  'O_1.0',
#  'ScO_0.0',
#  'Sc_0.0',
#  'Sc_1.0',
#  'TiO_0.0',
#  'Ti_0.0',
#  'Ti_1.0',
#  'VO_0.0',
#  'V_0.0',
#  'V_1.0',
#  'be',
#  'be_h',
#  'c',
#  'c2_h2',
#  'c2_h4',
#  'c2_h6',
#  'c_h',
#  'c_h2_singlet',
#  'c_h2_triplet',
#  'c_h3',
#  'c_h3_cl',
#  'c_h4',
#  'c_n',
#  'c_o',
#  'c_o2',
#  'c_s',
#  'cl',
#  'cl2',
#  'cl_f',
#  'cl_o',
#  'f',
#  'f2',
#  'h',
#  'h2_c_o',
#  'h2_o',
#  'h2_o2',
#  'h2_s',
#  'h3_c_o_h',
#  'h3_c_s_h',
#  'h_c_n',
#  'h_c_o',
#  'h_cl',
#  'h_f',
#  'h_o_cl',
#  'li',
#  'li2',
#  'li_f',
#  'li_h',
#  'n',
#  'n2',
#  'n2_h4',
#  'n_h',
#  'n_h2',
#  'n_h3',
#  'n_o',
#  'na',
#  'na2',
#  'na_cl',
#  'o',
#  'o2',
#  'o_h',
#  'p',
#  'p2',
#  'p_h2',
#  'p_h3',
#  's',
#  's2',
#  's_o',
#  's_o2',
#  'si',
#  'si2',
#  'si2_h6',
#  'si_h2_singlet',
# ...

# %%
shci_ref_db.to_csv('shci_ref_es.csv', index=False)

# %% [markdown]
# ## CCSD and CCSDT

# %%
i=1
# Replace 'your_file.csv' with the path to your CSV file
file_path = files[i]

# Load the CSV file into a DataFrame
df_ccsd_1 = pd.read_csv(file_path)

ccsd_df = df_ccsd_1[df_ccsd_1['method'] == 'CCSD ']
ccsdt_df = df_ccsd_1[df_ccsd_1['method'] == 'CCSDT']
ccsd_df_2 = ccsd_df.rename(columns={"energy": "CCSD"})
ccsdt_df_2 = ccsdt_df.rename(columns={"energy": "CCSDT"})

ccsd_df_2 = ccsd_df_2.drop(columns='method')

ccsdt_df_2 = ccsdt_df_2.drop(columns='method')


filtered_df = df_shci_2[df_shci_2['method'] == 'UCCSD(T)']

ccsdt_2 = filtered_df[['system', 'charge', 'basis', 'totalenergy']]

ccsdt_3 = ccsdt_2.rename(columns={"totalenergy": "CCSDT"})
ccsdt_3


filtered_df = df_shci_2[df_shci_2['method'] == 'UCCSD']

ccsd_2 = filtered_df[['system', 'charge', 'basis', 'totalenergy']]

ccsd_3 = ccsd_2.rename(columns={"totalenergy": "CCSD"})
ccsd_3

# %%
df_ccsd_1[df_ccsd_1['method'] == 'CCSDT']
# Out:
#         system method   basis      energy
# 2            h  CCSDT      2z   -0.499278
# 5            h  CCSDT     2dz   -0.499278
# 8            h  CCSDT      3z   -0.499810
# 11           h  CCSDT     3dz   -0.499810
# 14           h  CCSDT      4z   -0.499946
# ...        ...    ...     ...         ...
# 1804    si2_h6  CCSDT  cbs45d -581.734389
# 1805   c_h3_cl  CCSDT  cbs45d -499.626035
# 1806  h3_c_s_h  CCSDT  cbs45d -438.220849
# 1807    h_o_cl  CCSDT  cbs45d -535.477167
# 1808      s_o2  CCSDT  cbs45d -548.100754
#
# [670 rows x 4 columns]

# %%
df_ccsd_1[df_ccsd_1['method'] == 'CCSD ']
# Out:
#      system method basis      energy
# 1         h  CCSD     2z   -0.499278
# 4         h  CCSD    2dz   -0.499278
# 7         h  CCSD     3z   -0.499810
# 10        h  CCSD    3dz   -0.499810
# 13        h  CCSD     4z   -0.499946
# ...     ...    ...   ...         ...
# 1594   s_o2  CCSD    3dz -547.953125
# 1597   s_o2  CCSD     4z -548.008941
# 1600   s_o2  CCSD    4dz -548.017987
# 1603   s_o2  CCSD     5z -548.038147
# 1606   s_o2  CCSD    5dz -548.040181
#
# [536 rows x 4 columns]

# %%
result_df = pd.concat([ccsd_3, ccsd_df_2], ignore_index=True)

result_df
# Out:
#     system  charge basis        CCSD
# 0       Cu     0.0   vtz -197.417404
# 1       Cr     0.0   vtz  -86.706591
# 2       Cr     1.0   vtz  -86.461552
# 3       Mn     0.0   vtz -104.047781
# 4       Mn     1.0   vtz -103.781465
# ..     ...     ...   ...         ...
# 623   s_o2     NaN   3dz -547.953125
# 624   s_o2     NaN    4z -548.008941
# 625   s_o2     NaN   4dz -548.017987
# 626   s_o2     NaN    5z -548.038147
# 627   s_o2     NaN   5dz -548.040181
#
# [628 rows x 4 columns]

# %%
result_df_ccsd = pd.concat([ccsd_3, ccsd_df_2], ignore_index=True)

# Function to check if the entry is a float, convert to string if true, then concatenate
def process_row(row):
    if not pd.isna(row['charge']):  # Check if the entry is a float
        return f"{row['system']}_{str(row['charge'])}"  # Convert to string and concatenate
    else:
        return row['system']  # Return the first column entry as is

# Apply the function to each row
result_df_ccsd['system'] = result_df_ccsd.apply(process_row, axis=1)

result_df_ccsd = result_df_ccsd.drop(columns='charge')

result_df_ccsd
# Out:
#      system basis        CCSD
# 0    Cu_0.0   vtz -197.417404
# 1    Cr_0.0   vtz  -86.706591
# 2    Cr_1.0   vtz  -86.461552
# 3    Mn_0.0   vtz -104.047781
# 4    Mn_1.0   vtz -103.781465
# ..      ...   ...         ...
# 623    s_o2   3dz -547.953125
# 624    s_o2    4z -548.008941
# 625    s_o2   4dz -548.017987
# 626    s_o2    5z -548.038147
# 627    s_o2   5dz -548.040181
#
# [628 rows x 3 columns]

# %%
result_df_ccsdt = pd.concat([ccsdt_3, ccsdt_df_2], ignore_index=True)

# Function to check if the entry is a float, convert to string if true, then concatenate
def process_row(row):
    if not pd.isna(row['charge']):  # Check if the entry is a float
        return f"{row['system']}_{str(row['charge'])}"  # Convert to string and concatenate
    else:
        return row['system']  # Return the first column entry as is

# Apply the function to each row
result_df_ccsdt['system'] = result_df_ccsdt.apply(process_row, axis=1)

result_df_ccsdt = result_df_ccsdt.drop(columns='charge')

result_df_ccsdt
# Out:
#        system   basis       CCSDT
# 0      Fe_0.0     vdz -123.517339
# 1      Fe_1.0     vdz -123.233182
# 2      Cu_0.0     vdz -197.235506
# 3      Cu_1.0     vdz -196.966135
# 4       O_0.0     vtz  -15.826582
# ..        ...     ...         ...
# 757    si2_h6  cbs45d -581.734389
# 758   c_h3_cl  cbs45d -499.626035
# 759  h3_c_s_h  cbs45d -438.220849
# 760    h_o_cl  cbs45d -535.477167
# 761      s_o2  cbs45d -548.100754
#
# [762 rows x 3 columns]

# %%
result_df_ccsd.to_csv('ccsd_ref_es.csv', index=False)
result_df_ccsdt.to_csv('ccsdt_ref_es.csv', index=False)

# %%
# Input string
input_string = """# Geometry given in units of Bohr. h spin 1 H 0.0000000000 0.0000000000 0.0000000000 li spin 1 Li 0.0000000000 0.0000000000 0.0000000000 be spin 0 BE 0.0000000000 0.0000000000 0.0000000000 c spin 2 C 0.0000000000 0.0000000000 0.0000000000 n spin 3 N 0.0000000000 0.0000000000 0.0000000000 o spin 2 O 0.0000000000 0.0000000000 0.0000000000 f spin 1 F 0.0000000000 0.0000000000 0.0000000000 na spin 1 NA 0.0000000000 0.0000000000 0.0000000000 si spin 2 SI 0.0000000000 0.0000000000 0.0000000000 p spin 3 P 0.0000000000 0.0000000000 0.0000000000 s spin 2 S 0.0000000000 0.0000000000 0.0000000000 cl spin 1 CL 0.0000000000 0.0000000000 0.0000000000 li_h spin 0 LI 0.0000000000 0.0000000000 0.7538116965 H 0.0000000000 0.0000000000 -2.2616240621 be_h spin 1 BE 0.0000000000 0.0000000000 1.2674392200 H 0.0000000000 0.0000000000 -1.2674392200 c_h spin 1 C 0.0000000000 0.0000000000 0.3017892402 H 0.0000000000 0.0000000000 -1.8107354414 c_h2_triplet spin 2 C 0.0000000000 0.0000000000 0.1989314547 H 0.0000000000 -1.8701484265 -0.5968132614 H 0.0000000000 1.8701484265 -0.5968132614 c_h2_singlet spin 0 C 0.0000000000 0.0000000000 0.3278296643 H 0.0000000000 -1.6279989384 -0.9834700958 H 0.0000000000 1.6279989384 -0.9834700958 c_h3 spin 1 C 0.0000000000 0.0000000000 0.0000000000 H -1.0167670677 1.7610922207 0.0000000000 H -1.0167670677 -1.7610922207 0.0000000000 H 2.0335341354 0.0000000000 0.0000000000 c_h4 spin 0 C 0.0000000000 0.0000000000 0.0000000000 H 1.1849715779 -1.1849715779 -1.1849715779 H -1.1849715779 1.1849715779 -1.1849715779 H -1.1849715779 -1.1849715779 1.1849715779 H 1.1849715779 1.1849715779 1.1849715779 n_h spin 2 N 0.0000000000 0.0000000000 0.2447195154 H 0.0000000000 0.0000000000 -1.7130366079 n_h2 spin 1 N 0.0000000000 0.0000000000 0.2676985834 H -1.5144075093 0.0000000000 -0.9369261447 H 1.5144075093 0.0000000000 -0.9369261447 n_h3 spin 0 N 0.0000000000 0.0000000000 0.2149752284 H -0.8857051218 1.5340862715 -0.5016466607 H -0.8857051218 -1.5340862715 -0.5016466607 H 1.7714102436 0.0000000000 -0.5016466607 o_h spin 1 O 0.0000000000 0.0000000000 0.2035990779 H 0.0000000000 0.0000000000 -1.6288682124 h2_o spin 0 H -1.4308249289 0.0000000000 -0.8863003855 H 1.4308249289 0.0000000000 -0.8863003855 O 0.0000000000 0.0000000000 0.2215703721 h_f spin 0 H 0.0000000000 0.0000000000 -1.5592507070 F 0.0000000000 0.0000000000 0.1732500786 si_h2_singlet spin 0 SI 0.0000000000 0.0000000000 0.2474879640 H -2.0687699662 0.0000000000 -1.7324195273 H 2.0687699662 0.0000000000 -1.7324195273 si_h2_triplet spin 2 SI 0.0000000000 0.0000000000 0.1786148217 H -2.3899151028 0.0000000000 -1.2503037516 H 2.3899151028 0.0000000000 -1.2503037516 si_h3 spin 1 SI 0.0000000000 0.0000000000 0.1496228345 H -1.3303500878 2.3042339440 -0.6982386347 H -1.3303500878 -2.3042339440 -0.6982386347 H 2.6607001756 0.0000000000 -0.6982386347 si_h4 spin 0 SI 0.0000000000 0.0000000000 0.0000000000 H 1.6111331340 -1.6111331340 -1.6111331340 H -1.6111331340 1.6111331340 -1.6111331340 H -1.6111331340 -1.6111331340 1.6111331340 H 1.6111331340 1.6111331340 1.6111331340 p_h2 spin 1 P 0.0000000000 0.0000000000 -0.2185600386 H -1.9277661719 0.0000000000 1.6391993444 H 1.9277661719 0.0000000000 1.6391993444 p_h3 spin 0 P 0.0000000000 0.0000000000 0.2409778580 H -1.1208437265 1.9413582816 -1.2049081870 H -1.1208437265 -1.9413582816 -1.2049081870 H 2.2416874529 0.0000000000 -1.2049081870 h2_s spin 0 H -1.8156865235 0.0000000000 -1.5585704056 H 1.8156865235 0.0000000000 -1.5585704056 S 0.0000000000 0.0000000000 0.1948307493 h_cl spin 0 H 0.0000000000 0.0000000000 -2.2744741988 CL 0.0000000000 0.0000000000 0.1337925999 li2 spin 0 LI 0.0000000000 0.0000000000 -2.5256187826 LI 0.0000000000 0.0000000000 2.5256187826 li_f spin 0 F 0.0000000000 0.0000000000 1.4776712361 LI 0.0000000000 0.0000000000 -1.4776712361 c2_h2 spin 0 C 0.0000000000 0.0000000000 -1.1361032638 C 0.0000000000 0.0000000000 1.1361032638 H 0.0000000000 0.0000000000 -3.1439371258 H 0.0000000000 0.0000000000 3.1439371258 c2_h4 spin 0 C 0.000000000 0.000000000 0.000000000 C 0.000000000 0.000000000 2.508023735 H 1.740983898 0.000000000 -1.085783723 H -1.740983898 0.000000000 -1.085783723 H 1.740983898 0.000000000 3.593807457 H -1.740983898 0.000000000 3.593807457 c2_h6 spin 0 C 0.0000000000 0.0000000000 -1.4386483945 C 0.0000000000 0.0000000000 1.4386483945 H -1.6617535925 -0.9594138840 2.1829169747 H 1.6617535925 -0.9594138840 2.1829169747 H 0.0000000000 -1.9188277679 -2.1829169747 H 1.6617535925 0.9594138840 -2.1829169747 H -1.6617535925 0.9594138840 -2.1829169747 H 0.0000000000 1.9188277679 2.1829169747 c_n spin 1 C 0.0000000000 0.0000000000 1.1073794288 N 0.0000000000 0.0000000000 -1.1073794288 h_c_n spin 0 H 0.0000000000 0.0000000000 -2.8401825705 C 0.0000000000 0.0000000000 -0.8276999826 N 0.0000000000 0.0000000000 1.3516076155 c_o spin 0 C 0.0000000000 0.0000000000 1.0752540870 O 0.0000000000 0.0000000000 -1.0752540870 h_c_o spin 1 H 1.767383372 0.000000000 -1.193700313 C 0.000000000 0.000000000 0.000000000 O 0.000000000 0.000000000 2.222716663 h2_c_o spin 0 H -1.7690669834 0.0000000000 -2.0934384492 H 1.7690669834 0.0000000000 -2.0934384492 C 0.0000000000 0.0000000000 -1.0008555749 O 0.0000000000 0.0000000000 1.2739965691 h3_c_o_h spin 0 H -2.0540490007 1.8442554010 0.0000000000 H 1.6262830672 -1.9975140683 0.0000000000 H 0.8279739929 2.0250190301 -1.6809849654 H 0.8279739929 2.0250190301 1.6809849654 C -0.0877267495 1.2530187210 0.0000000000 O -0.0877267495 -1.4268621735 0.0000000000 n2 spin 0 N 0.0000000000 0.0000000000 -1.0370816221 N 0.0000000000 0.0000000000 1.0370816221 n2_h4 spin 0 N 0.1122505457 1.3501196282 -0.0803855930 N -0.1122505457 -1.3501196282 -0.0803855930 H 0.5895561278 2.0205227427 1.6458351020 H -0.5895561278 -2.0205227427 1.6458351020 H -1.5986022854 2.0625696108 -0.5287677360 H 1.5986022854 -2.0625696108 -0.5287677360 n_o spin 1 N 0.0000000000 0.0000000000 -1.1598382222 O 0.0000000000 0.0000000000 1.0148584444 o2 spin 2 O 0.0000000000 0.0000000000 -1.1409220651 O 0.0000000000 0.0000000000 1.1409220651 h2_o2 spin 0 H -1.6869016975 -1.4931291947 0.8801398788 H 1.6869016975 1.4931291947 0.8801398788 O -1.3709962041 0.0000000000 -0.1100198470 O 1.3709962041 0.0000000000 -0.1100198470 f2 spin 0 F 0.0000000000 0.0000000000 -1.3339575747 F 0.0000000000 0.0000000000 1.3339575747 c_o2 spin 0 C 0.0000000000 0.0000000000 0.0000000000 O 0.0000000000 0.0000000000 -2.1920821458 O 0.0000000000 0.0000000000 2.1920821458 na2 spin 0 NA 0.0000000000 0.0000000000 -2.9091386718 NA 0.0000000000 0.0000000000 2.9091386718 si2 spin 2 SI 0.0000000000 0.0000000000 -2.1221622842 SI 0.0000000000 0.0000000000 2.1221622842 p2 spin 0 P 0.0000000000 0.0000000000 -1.7890035926 P 0.0000000000 0.0000000000 1.7890035926 s2 spin 2 S 0.0000000000 0.0000000000 -1.7850351680 S 0.0000000000 0.0000000000 1.7850351680 cl2 spin 0 CL 0.0000000000 0.0000000000 -1.8782931455 CL 0.0000000000 0.0000000000 1.8782931455 na_cl spin 0 NA 0.0000000000 0.0000000000 0.0000000000 CL 0.0000000000 0.0000000000 4.4612651118 si_o spin 0 SI 0.0000000000 0.0000000000 1.0376296426 O 0.0000000000 0.0000000000 -1.8158565989 c_s spin 0 C 0.0000000000 0.0000000000 1.4513095586 S 0.0000000000 0.0000000000 -1.4513095586 s_o spin 2 S 0.0000000000 0.0000000000 0.9331466927 O 0.0000000000 0.0000000000 -1.8662933855 cl_o spin 1 CL 0.0000000000 0.0000000000 1.4815451744 O 0.0000000000 0.0000000000 -1.4815451744 cl_f spin 0 CL 0.0000000000 0.0000000000 1.5382369540 F 0.0000000000 0.0000000000 -1.5382369540 si2_h6 spin 0 SI 0.0000000000 0.0000000000 -2.2115557721 SI 0.0000000000 0.0000000000 2.2115557721 H -2.2717107717 -1.3115728255 3.1851066961 H 2.2717107717 -1.3115728255 3.1851066961 H 0.0000000000 -2.6231456511 -3.1851066961 H 2.2717107717 1.3115728255 -3.1851066961 H -2.2717107717 1.3115728255 -3.1851066961 H 0.0000000000 2.6231456511 3.1851066961 c_h3_cl spin 0 C 0.0000000000 0.0000000000 -2.1213308048 H -0.9712407341 1.6822382978 -2.7675093782 H -0.9712407341 -1.6822382978 -2.7675093782 H 1.9424814681 0.0000000000 -2.7675093782 CL 0.0000000000 0.0000000000 1.2370902206 h3_c_s_h spin 0 H 2.4151850856 -1.5678281732 0.0000000000 H -2.0620727773 2.7522536203 0.0000000000 H 0.8159421075 2.9203504161 -1.6837534140 H 0.8159421075 2.9203504161 1.6837534140 C -0.0902268570 2.1733908660 0.0000000000 S -0.0902268570 -1.2540920853 0.0000000000 h_o_cl spin 0 H -1.7072351491 2.4777898178 0.0000000000 O 0.0682946972 2.0711396825 0.0000000000 CL 0.0682946972 -1.1204185381 0.0000000000 s_o2 spin 0 S 0.0000000000 0.0000000000 0.0000000000 O 0.0000000000 -2.3377800194 1.3634373001 O 0.0000000000 2.3377800194 1.3634373001"""

# %%
geometries = []
lines = input_string.strip().split('\n')
current_geometry = {'atoms': [], 'spin': None, 'name': None}
systems = ['be',
 'be_h',
 'c',
 'c2_h2',
 'c2_h4',
 'c2_h6',
 'c_h',
 'c_h2_singlet',
 'c_h2_triplet',
 'c_h3',
 'c_h3_cl',
 'c_h4',
 'c_n',
 'c_o',
 'c_o2',
 'c_s',
 'cl',
 'cl2',
 'cl_f',
 'cl_o',
 'f',
 'f2',
 'h',
 'h2_c_o',
 'h2_o',
 'h2_o2',
 'h2_s',
 'h3_c_o_h',
 'h3_c_s_h',
 'h_c_n',
 'h_c_o',
 'h_cl',
 'h_f',
 'h_o_cl',
 'li',
 'li2',
 'li_f',
 'li_h',
 'n',
 'n2',
 'n2_h4',
 'n_h',
 'n_h2',
 'n_h3',
 'n_o',
 'na',
 'na2',
 'na_cl',
 'o',
 'o2',
 'o_h',
 'p',
 'p2',
 'p_h2',
 'p_h3',
 's',
 's2',
 's_o',
 's_o2',
 'si',
 'si2',
 'si2_h6',
 'si_h2_singlet',
 'si_h2_triplet',
 'si_h3',
 'si_h4',
 'si_o']
for line in lines:
    print(line)
# Out:
# # Geometry given in units of Bohr. h spin 1 H 0.0000000000 0.0000000000 0.0000000000 li spin 1 Li 0.0000000000 0.0000000000 0.0000000000 be spin 0 BE 0.0000000000 0.0000000000 0.0000000000 c spin 2 C 0.0000000000 0.0000000000 0.0000000000 n spin 3 N 0.0000000000 0.0000000000 0.0000000000 o spin 2 O 0.0000000000 0.0000000000 0.0000000000 f spin 1 F 0.0000000000 0.0000000000 0.0000000000 na spin 1 NA 0.0000000000 0.0000000000 0.0000000000 si spin 2 SI 0.0000000000 0.0000000000 0.0000000000 p spin 3 P 0.0000000000 0.0000000000 0.0000000000 s spin 2 S 0.0000000000 0.0000000000 0.0000000000 cl spin 1 CL 0.0000000000 0.0000000000 0.0000000000 li_h spin 0 LI 0.0000000000 0.0000000000 0.7538116965 H 0.0000000000 0.0000000000 -2.2616240621 be_h spin 1 BE 0.0000000000 0.0000000000 1.2674392200 H 0.0000000000 0.0000000000 -1.2674392200 c_h spin 1 C 0.0000000000 0.0000000000 0.3017892402 H 0.0000000000 0.0000000000 -1.8107354414 c_h2_triplet spin 2 C 0.0000000000 0.0000000000 0.1989314547 H 0.00
# ...

# %%
import re

# Given input string
input_string = """
# Geometry given in units of Bohr.
h spin 1 H 0.0000000000 0.0000000000 0.0000000000
li spin 1 Li 0.0000000000 0.0000000000 0.0000000000
be spin 0 BE 0.0000000000 0.0000000000 0.0000000000
c spin 2 C 0.0000000000 0.0000000000 0.0000000000
n spin 3 N 0.0000000000 0.0000000000 0.0000000000
o spin 2 O 0.0000000000 0.0000000000 0.0000000000
f spin 1 F 0.0000000000 0.0000000000 0.0000000000
na spin 1 NA 0.0000000000 0.0000000000 0.0000000000
si spin 2 SI 0.0000000000 0.0000000000 0.0000000000
p spin 3 P 0.0000000000 0.0000000000 0.0000000000
s spin 2 S 0.0000000000 0.0000000000 0.0000000000
cl spin 1 CL 0.0000000000 0.0000000000 0.0000000000
li_h spin 0 LI 0.0000000000 0.0000000000 0.7538116965 H 0.0000000000 0.0000000000 -2.2616240621
be_h spin 1 BE 0.0000000000 0.0000000000 1.2674392200 H 0.0000000000 0.0000000000 -1.2674392200
c_h spin 1 C 0.0000000000 0.0000000000 0.3017892402 H 0.0000000000 0.0000000000 -1.8107354414
c_h2_triplet spin 2 C 0.0000000000 0.0000000000 0.1989314547 H 0.0000000000 -1.8701484265 -0.5968132614 H 0.0000000000 1.8701484265 -0.5968132614
c_h2_singlet spin 0 C 0.0000000000 0.0000000000 0.3278296643 H 0.0000000000 -1.6279989384 -0.9834700958 H 0.0000000000 1.6279989384 -0.9834700958
c_h3 spin 1 C 0.0000000000 0.0000000000 0.0000000000 H -1.0167670677 1.7610922207 0.0000000000 H -1.0167670677 -1.7610922207 0.0000000000 H 2.0335341354 0.0000000000 0.0000000000
c_h4 spin 0 C 0.0000000000 0.0000000000 0.0000000000 H 1.1849715779 -1.1849715779 -1.1849715779 H -1.1849715779 1.1849715779 -1.1849715779 H -1.1849715779 -1.1849715779 1.1849715779 H 1.1849715779 1.1849715779 1.1849715779
n_h spin 2 N 0.0000000000 0.0000000000 0.2447195154 H 0.0000000000 0.0000000000 -1.7130366079
n_h2 spin 1 N 0.0000000000 0.0000000000 0.2676985834 H -1.5144075093 0.0000000000 -0.9369261447 H 1.5144075093 0.0000000000 -0.9369261447
n_h3 spin 0 N 0.0000000000 0.0000000000 0.2149752284 H -0.8857051218 1.5340862715 -0.5016466607 H -0.8857051218 -1.5340862715 -0.5016466607 H 1.7714102436 0.0000000000 -0.5016466607
o_h spin 1 O 0.0000000000 0.0000000000 0.2035990779 H 0.0000000000 0.0000000000 -1.6288682124
h2_o spin 0 H -1.4308249289 0.0000000000 -0.8863003855 H 1.4308249289 0.0000000000 -0.8863003855 O 0.0000000000 0.0000000000 0.2215703721
h_f spin 0 H 0.0000000000 0.0000000000 -1.5592507070 F 0.0000000000 0.0000000000 0.1732500786
si_h2_singlet spin 0 SI 0.0000000000 0.0000000000 0.2474879640 H -2.0687699662 0.0000000000 -1.7324195273 H 2.0687699662 0.0000000000 -1.7324195273
si_h2_triplet spin 2 SI 0.0000000000 0.0000000000 0.1786148217 H -2.3899151028 0.0000000000 -1.2503037516 H 2.3899151028 0.0000000000 -1.2503037516
si_h3 spin 1 SI 0.0000000000 0.0000000000 0.1496228345 H -1.3303500878 2.3042339440 -0.6982386347 H -1.3303500878 -2.3042339440 -0.6982386347 H 2.6607001756 0.0000000000 -0.6982386347
si_h4 spin 0 SI 0.0000000000 0.0000000000 0.0000000000 H 1.6111331340 -1.6111331340 -1.6111331340 H -1.6111331340 1.6111331340 -1.6111331340 H -1.6111331340 -1.6111331340 1.6111331340 H 1.6111331340 1.6111331340 1.6111331340
p_h2 spin 1 P 0.0000000000 0.0000000000 -0.2185600386 H -1.9277661719 0.0000000000 1.6391993444 H 1.9277661719 0.0000000000 1.6391993444
p_h3 spin 0 P 0.0000000000 0.0000000000 0.2409778580 H -1.1208437265 1.9413582816 -1.2049081870 H -1.1208437265 -1.9413582816 -1.2049081870 H 2.2416874529 0.0000000000 -1.2049081870
h2_s spin 0 H -1.8156865235 0.0000000000 -1.5585704056 H 1.8156865235 0.0000000000 -1.5585704056 S 0.0000000000 0.0000000000 0.1948307493
h_cl spin 0 H 0.0000000000 0.0000000000 -2.2744741988 CL 0.0000000000 0.0000000000 0.1337925999
li2 spin 0 LI 0.0000000000 0.0000000000 -2.5256187826 LI 0.0000000000 0.0000000000 2.5256187826
li_f spin 0 F 0.0000000000 0.0000000000 1.4776712361 LI 0.0000000000 0.0000000000 -1.4776712361
c2_h2 spin 0 C 0.0000000000 0.0000000000 -1.1361032638 C 0.0000000000 0.0000000000 1.1361032638 H 0.0000000000 0.0000000000 -3.1439371258 H 0.0000000000 0.0000000000 3.1439371258
c2_h4 spin 0 C 0.000000000 0.000000000 0.000000000 C 0.000000000 0.000000000 2.508023735 H 1.740983898 0.000000000 -1.085783723 H -1.740983898 0.000000000 -1.085783723 H 1.740983898 0.000000000 3.593807457 H -1.740983898 0.000000000 3.593807457
c2_h6 spin 0 C 0.0000000000 0.0000000000 -1.4386483945 C 0.0000000000 0.0000000000 1.4386483945 H -1.6617535925 -0.9594138840 2.1829169747 H 1.6617535925 -0.9594138840 2.1829169747 H 0.0000000000 -1.9188277679 -2.1829169747 H 1.6617535925 0.9594138840 -2.1829169747 H -1.6617535925 0.9594138840 -2.1829169747 H 0.0000000000 1.9188277679 2.1829169747
c_n spin 1 C 0.0000000000 0.0000000000 1.1073794288 N 0.0000000000 0.0000000000 -1.1073794288
h_c_n spin 0 H 0.0000000000 0.0000000000 -2.8401825705 C 0.0000000000 0.0000000000 -0.8276999826 N 0.0000000000 0.0000000000 1.3516076155
c_o spin 0 C 0.0000000000 0.0000000000 1.0752540870 O 0.0000000000 0.0000000000 -1.0752540870
h_c_o spin 1 H 1.767383372 0.000000000 -1.193700313 C 0.000000000 0.000000000 0.000000000 O 0.000000000 0.000000000 2.222716663
h2_c_o spin 0 H -1.7690669834 0.0000000000 -2.0934384492 H 1.7690669834 0.0000000000 -2.0934384492 C 0.0000000000 0.0000000000 -1.0008555749 O 0.0000000000 0.0000000000 1.2739965691
h3_c_o_h spin 0 H -2.0540490007 1.8442554010 0.0000000000 H 1.6262830672 -1.9975140683 0.0000000000 H 0.8279739929 2.0250190301 -1.6809849654 H 0.8279739929 2.0250190301 1.6809849654 C -0.0877267495 1.2530187210 0.0000000000 O -0.0877267495 -1.4268621735 0.0000000000
n2 spin 0 N 0.0000000000 0.0000000000 -1.0370816221 N 0.0000000000 0.0000000000 1.0370816221
n2_h4 spin 0 N 0.1122505457 1.3501196282 -0.0803855930 N -0.1122505457 -1.3501196282 -0.0803855930 H 0.5895561278 2.0205227427 1.6458351020 H -0.5895561278 -2.0205227427 1.6458351020 H -1.5986022854 2.0625696108 -0.5287677360 H 1.5986022854 -2.0625696108 -0.5287677360
n_o spin 1 N 0.0000000000 0.0000000000 -1.1598382222 O 0.0000000000 0.0000000000 1.0148584444
o2 spin 2 O 0.0000000000 0.0000000000 -1.1409220651 O 0.0000000000 0.0000000000 1.1409220651
h2_o2 spin 0 H -1.6869016975 -1.4931291947 0.8801398788 H 1.6869016975 1.4931291947 0.8801398788 O -1.3709962041 0.0000000000 -0.1100198470 O 1.3709962041 0.0000000000 -0.1100198470
f2 spin 0 F 0.0000000000 0.0000000000 -1.3339575747 F 0.0000000000 0.0000000000 1.3339575747
c_o2 spin 0 C 0.0000000000 0.0000000000 0.0000000000 O 0.0000000000 0.0000000000 -2.1920821458 O 0.0000000000 0.0000000000 2.1920821458
na2 spin 0 NA 0.0000000000 0.0000000000 -2.9091386718 NA 0.0000000000 0.0000000000 2.9091386718
si2 spin 2 SI 0.0000000000 0.0000000000 -2.1221622842 SI 0.0000000000 0.0000000000 2.1221622842
p2 spin 0 P 0.0000000000 0.0000000000 -1.7890035926 P 0.0000000000 0.0000000000 1.7890035926
s2 spin 2 S 0.0000000000 0.0000000000 -1.7850351680 S 0.0000000000 0.0000000000 1.7850351680
cl2 spin 0 CL 0.0000000000 0.0000000000 -1.8782931455 CL 0.0000000000 0.0000000000 1.8782931455
na_cl spin 0 NA 0.0000000000 0.0000000000 0.0000000000 CL 0.0000000000 0.0000000000 4.4612651118
si_o spin 0 SI 0.0000000000 0.0000000000 1.0376296426 O 0.0000000000 0.0000000000 -1.8158565989
c_s spin 0 C 0.0000000000 0.0000000000 1.4513095586 S 0.0000000000 0.0000000000 -1.4513095586
s_o spin 2 S 0.0000000000 0.0000000000 0.9331466927 O 0.0000000000 0.0000000000 -1.8662933855
cl_o spin 1 CL 0.0000000000 0.0000000000 1.4815451744 O 0.0000000000 0.0000000000 -1.4815451744
cl_f spin 0 CL 0.0000000000 0.0000000000 1.5382369540 F 0.0000000000 0.0000000000 -1.5382369540
si2_h6 spin 0 SI 0.0000000000 0.0000000000 -2.2115557721 SI 0.0000000000 0.0000000000 2.2115557721 H -2.2717107717 -1.3115728255 3.1851066961 H 2.2717107717 -1.3115728255 3.1851066961 H 0.0000000000 -2.6231456511 -3.1851066961 H 2.2717107717 1.3115728255 -3.1851066961 H -2.2717107717 1.3115728255 -3.1851066961 H 0.0000000000 2.6231456511 3.1851066961
c_h3_cl spin 0 C 0.0000000000 0.0000000000 -2.1213308048 H -0.9712407341 1.6822382978 -2.7675093782 H -0.9712407341 -1.6822382978 -2.7675093782 H 1.9424814681 0.0000000000 -2.7675093782 CL 0.0000000000 0.0000000000 1.2370902206
h3_c_s_h spin 0 H 2.4151850856 -1.5678281732 0.0000000000 H -2.0620727773 2.7522536203 0.0000000000 H 0.8159421075 2.9203504161 -1.6837534140 H 0.8159421075 2.9203504161 1.6837534140 C -0.0902268570 2.1733908660 0.0000000000 S -0.0902268570 -1.2540920853 0.0000000000
h_o_cl spin 0 H -1.7072351491 2.4777898178 0.0000000000 O 0.0682946972 2.0711396825 0.0000000000 CL 0.0682946972 -1.1204185381 0.0000000000
s_o2 spin 0 S 0.0000000000 0.0000000000 0.0000000000 O 0.0000000000 -2.3377800194 1.3634373001 O 0.0000000000 2.3377800194 1.3634373001
"""

# Splitting the input string by lines
lines = input_string.strip().split('\n')

# Initialize an empty dictionary to store the geometries
geometries = {}

# Define a function to parse each line and extract relevant data
def parse_line(line):
    match = re.match(r"(\w+)\s+spin\s+(\d+)\s+(.+)", line)
    if match:
        system_name = match.group(1)
        spin = int(match.group(2))
        coordinates = match.group(3).split()
        atoms = [(coordinates[i], float(coordinates[i+1]), float(coordinates[i+2]), float(coordinates[i+3])) for i in range(0, len(coordinates), 4)]
        return system_name, spin, atoms
    return None

# Process each line and store the data in the dictionary
current_system = None
for line in lines:
    parsed_data = parse_line(line)
    if parsed_data:
        current_system = parsed_data[0]
        geometries[current_system] = {
            'spin': parsed_data[1],
            'atoms': parsed_data[2]
        }
    else:
        if current_system:
            # Append additional atoms to the current system
            coordinates = line.split()
            atoms = [(coordinates[i], float(coordinates[i+1]), float(coordinates[i+2]), float(coordinates[i+3])) for i in range(0, len(coordinates), 4)]
            geometries[current_system]['atoms'].extend(atoms)

# Display the parsed geometries
for system, data in geometries.items():
    print(f"System: {system}")
    print(f"  Spin: {data['spin']}")
    for atom in data['atoms']:
        print(f"  Atom: {atom[0]}  Coordinates: ({atom[1]}, {atom[2]}, {atom[3]})")
# Out:
# System: h
#   Spin: 1
#   Atom: H  Coordinates: (0.0, 0.0, 0.0)
# System: li
#   Spin: 1
#   Atom: Li  Coordinates: (0.0, 0.0, 0.0)
# System: be
#   Spin: 0
#   Atom: BE  Coordinates: (0.0, 0.0, 0.0)
# System: c
#   Spin: 2
#   Atom: C  Coordinates: (0.0, 0.0, 0.0)
# System: n
#   Spin: 3
#   Atom: N  Coordinates: (0.0, 0.0, 0.0)
# System: o
#   Spin: 2
#   Atom: O  Coordinates: (0.0, 0.0, 0.0)
# System: f
#   Spin: 1
#   Atom: F  Coordinates: (0.0, 0.0, 0.0)
# System: na
#   Spin: 1
#   Atom: NA  Coordinates: (0.0, 0.0, 0.0)
# System: si
#   Spin: 2
#   Atom: SI  Coordinates: (0.0, 0.0, 0.0)
# System: p
#   Spin: 3
#   Atom: P  Coordinates: (0.0, 0.0, 0.0)
# System: s
#   Spin: 2
#   Atom: S  Coordinates: (0.0, 0.0, 0.0)
# System: cl
#   Spin: 1
#   Atom: CL  Coordinates: (0.0, 0.0, 0.0)
# System: li_h
#   Spin: 0
#   Atom: LI  Coordinates: (0.0, 0.0, 0.7538116965)
#   Atom: H  Coordinates: (0.0, 0.0, -2.2616240621)
# System: be_h
#   Spin: 1
# ...

# %%
len(geometries.items())
# Out:
# 67

# %%
len(systems) - len(['CrO_0.0',
 'Cr_0.0',
 'Cr_1.0',
 'CuO_0.0',
 'Cu_0.0',
 'Cu_1.0',
 'FeO_0.0',
 'Fe_0.0',
 'Fe_1.0',
 'MnO_0.0',
 'Mn_0.0',
 'Mn_1.0',
 'O_0.0',
 'O_1.0',
 'ScO_0.0',
 'Sc_0.0',
 'Sc_1.0',
 'TiO_0.0',
 'Ti_0.0',
 'Ti_1.0',
 'VO_0.0',
 'V_0.0',
 'V_1.0'])
# Out:
# 67

# %%
from pyscf import gto, scf

# Parsed geometries dictionary from the previous code
geometries = {
    'h': {'spin': 1, 'atoms': [('H', 0.0, 0.0, 0.0)]}
    # Add other systems here...
}

# List of basis sets
basis_sets = ['cc-pVDZ', 'cc-pVTZ', 'cc-pVQZ', 'cc-pV5Z']

# Function to create a PySCF molecule and perform Hartree-Fock calculation
def perform_hartree_fock(system_name, system_data, basis):
    atom_list = system_data['atoms']
    spin = system_data['spin']
    
    atom_str = ''
    for atom in atom_list:
        atom_str += f'{atom[0]} {atom[1]} {atom[2]} {atom[3]};'
    
    mol = gto.M(atom=atom_str, basis=basis, spin=spin)
    mf = scf.RHF(mol) if spin == 0 else scf.UHF(mol)
    energy = mf.kernel()
    
    return energy

# Perform Hartree-Fock calculations for all systems and basis sets
results = {}
for system_name, system_data in geometries.items():
    results[system_name] = {}
    for basis in basis_sets:
        energy = perform_hartree_fock(system_name, system_data, basis)
        results[system_name][basis] = energy
        print(f"System: {system_name}, Basis: {basis}, Hartree-Fock Energy: {energy}")

# Convert results to DataFrame for better display
# import pandas as pd
# results_df = pd.DataFrame(results).T
# result_df
# Out:
# converged SCF energy = -0.499278403419583  <S^2> = 0.75  2S+1 = 2
# System: h, Basis: cc-pVDZ, Hartree-Fock Energy: -0.49927840341958307
# converged SCF energy = -0.499809811301843  <S^2> = 0.75  2S+1 = 2
# System: h, Basis: cc-pVTZ, Hartree-Fock Energy: -0.49980981130184265
# converged SCF energy = -0.499945568582989  <S^2> = 0.75  2S+1 = 2
# System: h, Basis: cc-pVQZ, Hartree-Fock Energy: -0.49994556858298855
# converged SCF energy = -0.499994535158902  <S^2> = 0.75  2S+1 = 2
# System: h, Basis: cc-pV5Z, Hartree-Fock Energy: -0.4999945351589018
